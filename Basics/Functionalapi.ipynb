# %% [markdown]
# <a href="https://colab.research.google.com/github/officialkalpesh3170/TensorFlow/blob/main/Basics/Functionalapi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.models import Model
from keras.layers import *
x = Input(shape=(32,))

# %%
h1=Dense(128,activation='relu')(x)
h2=Dense(64,activation='relu')(h1)

o1=Dense(1,activation='linear')(h2)
o2=Dense(1,activation='linear')(h2)

model=Model(inputs=x,outputs=[o1,o2])

# %%
from keras.utils import plot_model
plot_model(model,show_shapes=True)
